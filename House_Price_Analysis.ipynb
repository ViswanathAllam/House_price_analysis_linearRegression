# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
house_df=pd.read_csv('House_Price.csv',header=0)

# %%
house_df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
house_df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %% [markdown]
# ### Bivariate Analysis
# 1. scatter plot
# 2. correlation

# %%
sns.jointplot(x='n_hot_rooms',y='price',data=house_df)

# %%
sns.jointplot(x='rainfall',y='price',data=house_df)

# %%
sns.jointplot(x='room_num',y='price',data=house_df)

# %%
sns.jointplot(x='crime_rate',y='price',data=house_df)

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# ## capping and flooring for outlier treatment

# %%
np.percentile(house_df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
uv=np.percentile(house_df.n_hot_rooms,[99])[0]

# %%
uv
# Out:
# 15.399519999999999

# %%
house_df[house_df.n_hot_rooms>uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
house_df.n_hot_rooms[house_df.n_hot_rooms>3*uv]=3*uv
# Out:
# <ipython-input-14-7c55379dd4a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_df.n_hot_rooms[house_df.n_hot_rooms>3*uv]=3*uv

# %%
lv=np.percentile(house_df.rainfall,[1])[0]

# %%
lv
# Out:
# 20.0

# %%
house_df.rainfall[(house_df.rainfall<0.3*lv)]=0.3*lv
# Out:
# <ipython-input-17-a0f1d704c570>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_df.rainfall[(house_df.rainfall<0.3*lv)]=0.3*lv

# %%
house_df[(house_df.rainfall<lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         6     YES  0.044019

# %%
sns.jointplot(x='rainfall',y='price',data=house_df)

# %%
house_df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %% [markdown]
# ### missing value imputation

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
house_df.n_hos_beds=house_df.n_hos_beds.fillna(house_df.n_hos_beds.mean())

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
house_df.crime_rate=np.log(1+house_df.crime_rate)

# %%
sns.jointplot(x='crime_rate',y='price',data=house_df)

# %%
house_df['avg_dist']=house_df.dist1+house_df.dist2+house_df.dist3+house_df.dist4 / 4

# %%
house_df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
del house_df['dist1']
del house_df['dist2']
del house_df['dist3']
del house_df['dist4']

# %%
house_df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.864050   39.187747
# ...

# %% [markdown]
# * Creating dummy variables

# %%
house_df=pd.get_dummies(house_df)

# %%
house_df.head(5)
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347   13.3425
# 1       9.14       7.332     12.17280        42  0.046146   16.0750
# 2       4.03       7.394     46.19856        38  0.045764   16.1425
# 3       2.94       9.268     11.26720        45  0.047151   19.7900
# 4       5.33       8.824     11.28960        55  0.039474   19.8550
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del house_df['airport_NO']
del house_df['waterbody_None']
del house_df['bus_ter_YES']

# %% [markdown]
# ## Correlation Analysis
# ![image.png](attachment:image.png)

# %%
house_df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# avg_dist                  0.249330   -0.587321   -0.707936 -0.769609
# ...

# %% [markdown]
# # Linear Regression
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)

# %% [markdown]
# ##### * residual standard error (RSE) is the average amount that the response will deviate from a true regression line.
#        RSE is considered to measure lack of fit of model to data.

# %%
# using stats models
import statsmodels.api as sm

# %%
X=sm.add_constant(house_df['room_num'])

# %%
lm=sm.OLS(house_df['price'],X).fit() #simple linear regression method with single variable

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Mon, 24 May 2021   Prob (F-statistic):           1.31e-74
# Time:                        16:03:16   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
# !pip install sklearn --upgrade --q 
from sklearn.linear_model import LinearRegression

# %%
y=house_df['price']
x=house_df[['room_num']]

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# -34.65924312309721

# %%
lr.coef_
# Out:
# array([9.09966966])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-e2fe17c625f0> in <module>
# ----> 1 lr.F_static
#
# AttributeError: 'LinearRegression' object has no attribute 'F_static'

# %%
help(lr)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  normalize : bool, default=False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
# ...

# %%
pred_y=lr.predict(x)

# %%
sns.jointplot(x=house_df['room_num'],y=house_df['price'],kind='reg')
sns.jointplot(x=house_df['room_num'],y=pred_y,kind='reg')

# %% [markdown]
# ### Multiple Regression

# %%
x_mul=house_df.drop(['price'],axis=1)

# %%
y_mul=house_df['price']

# %%
x_mul_const=sm.add_constant(x_mul)
x_mul_const.head(10)
# Out:
#    const  crime_rate  resid_area  air_qual  room_num    age  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575   65.2      24.7
# 1    1.0    0.026944       37.07     0.469     6.421   78.9      22.2
# 2    1.0    0.026924       37.07     0.469     7.185   61.1      22.2
# 3    1.0    0.031857       32.18     0.458     6.998   45.8      21.3
# 4    1.0    0.066770       32.18     0.458     7.147   54.2      21.3
# 5    1.0    0.029413       32.18     0.458     6.430   58.7      21.3
# 6    1.0    0.084608       37.87     0.524     6.012   66.6      24.8
# 7    1.0    0.135012       37.87     0.524     6.172   96.1      24.8
# 8    1.0    0.191645       37.87     0.524     5.631  100.0      24.8
# 9    1.0    0.157038       37.87     0.524     6.004   85.9      24.8
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347   13.3425
# ...

# %%
mul_reg=sm.OLS(y_mul,x_mul_const).fit()

# %%
mul_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.722
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     79.20
# Date:                Mon, 24 May 2021   Prob (F-statistic):          2.07e-124
# Time:                        17:02:09   Log-Likelihood:                -1515.9
# No. Observations:                 506   AIC:                             3066.
# Df Residuals:                     489   BIC:                             3138.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
lr_mul=LinearRegression().fit(x_mul,y_mul)

# %%
print(lr_mul.intercept_,lr_mul.coef_) #beta0=intercept, betai=coefficients of each variable
# Out:
# -6.952828013275781 [ 2.82007604e-02 -4.21440663e-02 -2.08696836e+01  4.01225850e+00
#  -5.41583153e-03  1.01283330e+00 -5.78911771e-01  3.37956449e-01
#   8.67024479e-02  1.61623192e-02  5.88878459e+01 -3.73831565e-01
#   1.11212683e+00  2.59226545e-01 -6.96280803e-01 -2.80707792e-01]

# %% [markdown]
# #### Train_test_split of house_df data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_mul,y_mul,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 220    0.306079       36.20     0.507     6.951  88.5      22.6       9.71
# 71     0.147350       40.81     0.413     5.961  17.5      20.8       9.88
# 240    0.107320       34.93     0.428     6.897  54.3      23.4      11.38
# 6      0.084608       37.87     0.524     6.012  66.6      24.8      12.43
# 417    3.293634       48.10     0.679     5.304  89.1      19.8      26.64
# ..          ...         ...       ...       ...   ...       ...        ...
# 323    0.249918       37.38     0.493     5.708  74.3      20.4      11.74
# 192    0.083090       33.44     0.437     7.178  26.3      24.8       2.87
# 117    0.140614       40.01     0.547     6.021  82.6      22.2      10.30
# 47     0.206420       36.91     0.448     6.030  85.5      22.1      18.80
# 172    0.130274       34.05     0.510     5.572  88.5      23.4      14.69
#
# ...

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (404, 16) (404,) (102, 16) (102,)

# %%
lm_a=LinearRegression()
lm_a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_p=lm_a.predict(x_test)

# %%
y_train_p=lm_a.predict(x_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_p)
# Out:
# 0.5480833791735421

# %%
r2_score(y_train,y_train_p)
# Out:
# 0.7576011792707198

# %% [markdown]
# ##### Ridge regression and lasso shrinkage techniques
# first need to standardizing the data

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.StandardScaler().fit(x_train)

# %%
x_train_s=scaler.transform(x_train)

# %%
x_test_s=scaler.transform(x_test)

# %%
from sklearn.linear_model import Ridge

# %%
lr_ridge=Ridge(alpha=0.6)
lr_ridge.fit(x_train_s,y_train)
# Out:
# Ridge(alpha=0.6)

# %%
r2_score(y_test,lr_ridge.predict(x_test_s))
# Out:
# 0.5478940137093267

# %%
from sklearn.model_selection import validation_curve

# %%
param_range=np.logspace(-2,8,100)
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores,test_scores=validation_curve(Ridge(),x_train_s,y_train,'alpha',param_range,scoring='r2')
# Out:
# C:\Users\Allam\anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
train_mean=np.mean(train_scores,axis=1)

# %%
test_mean=np.mean(test_scores,axis=1)

# %%
max(test_mean)
# Out:
# 0.7387076824991198

# %%
sns.jointplot(x=np.log(param_range),y=test_mean) #plot between lambda and test_means

# %%
np.where(test_mean==max(test_mean))
# Out:
# (array([30], dtype=int64),)

# %%
param_range[30]
# Out:
# 10.722672220103231

# %%
lr_ridge_best=Ridge(alpha=param_range[30])

# %%
lr_ridge_best.fit(x_train_s,y_train)
# Out:
# Ridge(alpha=10.722672220103231)

# %%
r2_score(y_train,lr_ridge_best.predict(x_train_s))
# Out:
# 0.7568235431601361

# %%
r2_score(y_test,lr_ridge_best.predict(x_test_s))
# Out:
# 0.5442255721280487

# %%
from sklearn.linear_model import Lasso

# %%
lm_l=Lasso(alpha=0.6)

# %% [markdown]
# ### In similar way we can do lasso method and optimum value for alpha can be found out .
